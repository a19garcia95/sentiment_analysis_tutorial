# %% [markdown]
# <a href="https://colab.research.google.com/github/a19garcia95/sentiment_analysis_tutorial/blob/master/sentiment_analysis_tutorial.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pandas
# !pip install tweepy
# !pip install vaderSentiment
# Out:
# Requirement already satisfied: pandas in /usr/local/lib/python3.6/dist-packages (0.22.0)
# Requirement already satisfied: python-dateutil>=2 in /usr/local/lib/python3.6/dist-packages (from pandas) (2.5.3)
# Requirement already satisfied: numpy>=1.9.0 in /usr/local/lib/python3.6/dist-packages (from pandas) (1.14.6)
# Requirement already satisfied: pytz>=2011k in /usr/local/lib/python3.6/dist-packages (from pandas) (2018.9)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.6/dist-packages (from python-dateutil>=2->pandas) (1.11.0)
# Requirement already satisfied: tweepy in /usr/local/lib/python3.6/dist-packages (3.6.0)
# Requirement already satisfied: requests>=2.11.1 in /usr/local/lib/python3.6/dist-packages (from tweepy) (2.18.4)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.6/dist-packages (from tweepy) (1.2.0)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.6/dist-packages (from tweepy) (1.11.0)
# Requirement already satisfied: PySocks>=1.5.7 in /usr/local/lib/python3.6/dist-packages (from tweepy) (1.6.8)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests>=2.11.1->tweepy) (2018.11.29)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests>=2.11.1->tweepy) (3.0.4)
# Requirement already satisfied: urllib3<1.23,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests>=2.11.1->tweepy) (1.22)
# Requirement already satisfied: idna<2.7,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests>=2.11.1->tweepy) (2.6)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.6/dist-packages (from requests-oauthlib>=0.7.0->tweepy) (3.0.1)
# Collecting vaderSentiment
#   Downloading https://files.pythonhosted.org/packages/86/9e/c53e1fc61aac5ee490a6ac5e21b1ac04e55a7c2aba647bb8411c9aadf24e/vaderSentiment-3.2.1-py2.py3-none-any.whl (125kB)
#     100% |████████████████████████████████| 133kB 3.9MB/s
# Installing collected packages: vaderSentiment
# Successfully installed vaderSentiment-3.2.1

# %%
import tweepy
import pandas as pd
from nltk.sentiment.vader import SentimentIntensityAnalyzer

# %%
#My Twitter API Authentication Variables
consumer_key = ''
consumer_secret = ''
access_token = ''
access_token_secret = ''

# %%
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)

api = tweepy.API(auth)

tweets = api.search('Venezuela', count=200)


data = pd.DataFrame(data=[tweet.text for tweet in tweets], columns=['Tweets'])

display(data.head(10))


print(tweets[0].created_at)
# Out:
#                                               Tweets
# 0  RT @davidakin: Freeland to Lima Group: "The da...
# 1  RT @VVSinMiedo: Maduro no solo acabó con Venez...
# 2  RT @pascual_serrano: ¿Cómo creéis que le irá a...
# 3  RT @alcaldeledezma: Mensaje a los Guerreros de...
# 4  RT @POLITICATOTALpe: Durante una rueda de pren...
# 5  RT @Dave_S001: Trudeau's #Venezuela coup could...
# 6  RT @RonaldVermeij: @Ian56789 @2lindamaria And ...
# 7  RT @SuNoticiero: #4feb Canadá proporcionará $5...
# 8  RT @BorisYopo: Chile se incendia en el centro-...
# 9  RT @Dreuz_1fo: Quel homme détestable, ce Mélen...
# 2019-02-04 22:48:24

# %%
import nltk
nltk.download('vader_lexicon')
# Out:
# [nltk_data] Downloading package vader_lexicon to /root/nltk_data...
# True

# %%
sid = SentimentIntensityAnalyzer()


listy = []

for index, row in data.iterrows():
  ss = sid.polarity_scores(row["Tweets"])
  listy.append(ss)
  
se = pd.Series(listy)
data['polarity'] = se.values

display(data.head(100))
# Out:
#                                                Tweets  \
# 0   RT @davidakin: Freeland to Lima Group: "The da...
# 1   RT @VVSinMiedo: Maduro no solo acabó con Venez...
# 2   RT @pascual_serrano: ¿Cómo creéis que le irá a...
# 3   RT @alcaldeledezma: Mensaje a los Guerreros de...
# 4   RT @POLITICATOTALpe: Durante una rueda de pren...
# 5   RT @Dave_S001: Trudeau's #Venezuela coup could...
# 6   RT @RonaldVermeij: @Ian56789 @2lindamaria And ...
# 7   RT @SuNoticiero: #4feb Canadá proporcionará $5...
# 8   RT @BorisYopo: Chile se incendia en el centro-...
# 9   RT @Dreuz_1fo: Quel homme détestable, ce Mélen...
# 10  Grupo de #Lima no abordó opción militar en #Ve...
# 11  RT @CGurisattiNTN24: Sin amenazas de guerra, s...
# 12  RT @PanAmPost_es: Si los militares deciden aba...
# 13  RT @ngotranslations: @ani_ddhh @moo2n @Aledema...
# 14  RT @LNFranco_FI: #Venezuela L'UE pas si unie q...
# 15  RT @RenovaMidia: O músico Roger Waters está se...
# 16  RT @oscarcerda56: Cadem y Venezuela 🇻🇪👇!!\n•77...
# 17  RT @secretstranger9: Maduro now appears to be ...
# 18  RT @RevistaSemana: Las manifestaciones en el p...
# 19  @Julio28502364 @zeballosmigues @Ernesto6419857...
# 20  RT @Franklin_Graham: The political climate in ...
# 21  RT @FloryCantoX: 📹RT/Comparte 🔄\n\nDeclaracion...
# 22  RT @JMoPeriodista: El emblema de los camiones ...
# 23  Guaido convoca a conferencia de ayuda sobre Ve...
# 24  RT @IdaniaChirinos: El apoyo a #Venezuela se m...
# 25  A veces no se que decir. Un español me coquete...
# 26  RT @comanditocomun1: Somos soberanía, paz y am...
# 27  RT @jonathanmartinz: La historia es propensa a...
# 28  RT @ElyangelicaNews: #AHORA 8:22am (COL) se ha...
# 29  RT @TAMARA_SUJU: Así vamos #Venezuela! España,...
# ..                                                ...
# 65  RT @anavescobar: #AHORA Intentan allanar resid...
# 66  RT @trish_regan: A communist one, Bernie? Or j...
# 67  @Rafaelita82 @precioreducido Venezuela es un e...
# 68  RT @beerAndGin: Los Hashtags trending en #Vene...
# 69  RT @theintercept: Elliott Abrams is an unrepen...
# 70  #SomosSudeaseg || Han pasado 27 años desde aqu...
# 71  RT @pn1que: El Gobierno de España no puede rec...
# 72  RT @melnicksergio: la Sra no se atreve a ir a ...
# 73  RT @CarmenClariana: @Yo_Soy_Asin El petroleo d...
# 74  RT @BeatrizTalegon: Lo que @sanchezcastejon va...
# 75  RT @jorgesuarezv: Dice Maduro que todo lo que ...
# 76  RT @agarzon: Seguro que esta imagen ayuda a en...
# 77  RT @ngotranslations: @ani_ddhh @moo2n @Aledema...
# 78  RT @marcorubio: 13 European nations now recogn...
# 79  RT @Trump_VZLA: URGENTE.\n\nEl gobierno de Can...
# 80  RT @jmrodri2017: ¿A qué juega Gustavo Petro co...
# 81  no se piquen si ustedes saben que mérida es lo...
# 82  RT @pnique: Guaidó no tiene el control efectiv...
# 83  RT @jeremycorbyn: Great to meet Bolivia’s Vice...
# 84  RT @Tesa29053098: #FelizLunes \n@sanchezcastej...
# 85  Y los títeres del Grupo de Lima solo están pre...
# 86  RT @DigitalSevilla: Roger Waters convoca una m...
# 87  Es curioso ver a ciertos sectores de la izquie...
# 88  #INTERNACIONALES: ONG registra 966 "presos pol...
# 89  RT @elpce: Suspendemos cualquier colaboración ...
# 90  RT @jaarreaza: La República Bolivariana de Ven...
# 91  RT @venezuelafrance: La carte qui montre les p...
# 92  RT @ManuelBelgranoV: VERDADES- La pregunta es ...
# 93  RT @Tonicanto1: Algunos policías incumplen las...
# 94  RT @ConflictsW: Military pilot Hector Luis Gue...
#
#                                              polarity
# 0   {'neg': 0.127, 'neu': 0.873, 'pos': 0.0, 'comp...
# 1   {'neg': 0.145, 'neu': 0.855, 'pos': 0.0, 'comp...
# 2   {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 3   {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 4   {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 5   {'neg': 0.0, 'neu': 0.892, 'pos': 0.108, 'comp...
# 6   {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 7   {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 8   {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 9   {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 10  {'neg': 0.136, 'neu': 0.864, 'pos': 0.0, 'comp...
# 11  {'neg': 0.153, 'neu': 0.847, 'pos': 0.0, 'comp...
# 12  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 13  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 14  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 15  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 16  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 17  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 18  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 19  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 20  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 21  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 22  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 23  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 24  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 25  {'neg': 0.095, 'neu': 0.905, 'pos': 0.0, 'comp...
# 26  {'neg': 0.0, 'neu': 0.789, 'pos': 0.211, 'comp...
# 27  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 28  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 29  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# ..                                                ...
# 65  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 66  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 67  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 68  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 69  {'neg': 0.312, 'neu': 0.592, 'pos': 0.095, 'co...
# 70  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 71  {'neg': 0.091, 'neu': 0.909, 'pos': 0.0, 'comp...
# 72  {'neg': 0.196, 'neu': 0.804, 'pos': 0.0, 'comp...
# 73  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 74  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 75  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 76  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 77  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 78  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 79  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 80  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 81  {'neg': 0.104, 'neu': 0.806, 'pos': 0.09, 'com...
# 82  {'neg': 0.1, 'neu': 0.9, 'pos': 0.0, 'compound...
# 83  {'neg': 0.0, 'neu': 0.83, 'pos': 0.17, 'compou...
# 84  {'neg': 0.128, 'neu': 0.872, 'pos': 0.0, 'comp...
# 85  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 86  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 87  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 88  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 89  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 90  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 91  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 92  {'neg': 0.091, 'neu': 0.909, 'pos': 0.0, 'comp...
# 93  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 94  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
#
# [95 rows x 2 columns]
